# %% [markdown]
# # 01 — Data Exploration
# Load the demand data, validate it, and explore the series.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from src.utils.config_loader import load_config
config = load_config()

# %%
from src.data_loading.loader import load_data
df = load_data(config)
df.head()

# %%
from src.validation.validator import run_validation
report = run_validation(df)
report

# %%
import matplotlib.pyplot as plt
sid = df['series_id'].iloc[0]
g = df[df['series_id'] == sid]
g.plot(x='date', y='sales', figsize=(12, 4), title=sid, color='#2a78d6', legend=False)
plt.show()

# %%
df.groupby('series_id')['sales'].describe()
