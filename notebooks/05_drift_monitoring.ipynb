# %% [markdown]
# # 05 — Drift Monitoring & Retraining Triggers

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from src.utils.config_loader import load_config
config = load_config()

# %%
import pandas as pd
from src.constants import FEATURES_PATH
from src.monitoring.drift_detector import detect_drift

features = pd.read_parquet(FEATURES_PATH)
report = detect_drift(features, config)
report['status'], report['recommendation']

# %%
pd.DataFrame(report['features'])

# %%
from src.monitoring.performance_monitor import check_performance
check_performance(features, config)

# %%
from src.retraining.orchestrator import check_triggers
triggers = check_triggers(features, config)
triggers['should_retrain'], triggers['reasons']
