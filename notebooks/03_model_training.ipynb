# %% [markdown]
# # 03 — Model Training
# Run walk-forward CV over all enabled models. Logs every fold to MLflow.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from src.utils.config_loader import load_config
config = load_config()

# %%
import pandas as pd
from src.constants import FEATURES_PATH
from src.training.train_pipeline import run_training

features = pd.read_parquet(FEATURES_PATH)  # produced by main.py or notebook 02
summary = run_training(features, config)
summary['best_model'], summary['avg_cv_mape']

# %%
pd.DataFrame(summary['comparison'])
